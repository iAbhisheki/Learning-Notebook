# %% [markdown]
# # 🏆 Capstone 3 — Production RAG Agent---**Skills Used:** ALL notebooks (01–17)## Project BriefBuild a **production-ready** RAG agent that combines everything:1. Multi-model RAG pipeline with hybrid search2. Agent layer with tools, planning, and memory3. Guardrails at every layer4. Evaluation and monitoring5. Performance optimization (caching, batch embedding)### Requirements| Layer | Components ||-------|-----------|| **Data** | Document ingestion, chunking, vector DB || **Retrieval** | Hybrid search, reranking, context optimization || **Agent** | ReAct + planning, tool use, memory || **Safety** | Input/output guardrails, prompt injection defense || **Evaluation** | Faithfulness, relevance, hallucination detection || **Performance** | Semantic caching, streaming, batch embedding || **Observability** | Full trace logging, metrics, error tracking |### Architecture```User Query → [Input Guard] → [Cache Check] → [Router]                                                  ↓                                          ┌───────┼───────┐                                         RAG    Agent    Direct                                          ↓       ↓        ↓                                      Retrieve  Tools    Answer                                          ↓       ↓                                       Generate  Reflect                                          └───────┼───────┘                                                  ↓                                          [Output Guard]                                                  ↓                                          [Evaluation]                                                  ↓                                           Final Response + Metrics```### Grading Rubric- ✅ End-to-end pipeline works reliably- ✅ Guardrails block injection attempts- ✅ Caching reduces redundant LLM calls- ✅ Evaluation scores logged per response- ✅ Tool usage integrated for enhanced answers- ⭐ Bonus: Query routing (simple → cheap model, complex → expensive)- ⭐ Bonus: Conversation memory across queries

# %% [markdown]
# ## Step 1: Foundation

# %%
import os, sys
import litellm

from setup_llm import DEFAULT_MODEL, is_proxy_mode

mode = "🔗 proxy" if is_proxy_mode() else "🔑 direct"
print(f"🤖 Model: {DEFAULT_MODEL} ({mode})")

# %% [markdown]
# ## Step 2: All Sub-Systems

# %%
# TODO: Integrate all sub-systems:# - VectorStore (from NB06)# - HybridRetriever (from NB05)# - SemanticCache (from NB17)# - InputGuardrails (from NB16)# - OutputGuardrails (from NB16)# - RAGEvaluator (from NB15)# - VectorMemory (from NB09)# - ToolRegistry (from NB07)# Each should be an independent, reusable module

# %% [markdown]
# ## Step 3: The Agent

# %%
# TODO: Build the main agent classclass ProductionRAGAgent:    def __init__(self):        pass  # Wire all sub-systems together        def query(self, user_input):        # 1. Input guardrails        # 2. Cache check        # 3. Route (RAG vs direct vs agent)        # 4. Retrieve + Generate OR Agent Loop        # 5. Output guardrails        # 6. Evaluate        # 7. Cache store        # 8. Return response + metrics        pass

# %% [markdown]
# ## Step 4: Test & Demo

# %%
# TODO: Comprehensive testing# - Normal queries# - Injection attempts# - Cache hit verification# - Evaluation logging# - Performance metrics# agent = ProductionRAGAgent()# agent.query("What is the main theme of the documents?")

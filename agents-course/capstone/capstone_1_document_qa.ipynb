# %% [markdown]
# # 🏆 Capstone 1 — Intelligent Document Q&A System---**Skills Used:** Notebooks 01–06 (LLM, Embeddings, RAG, Vector DB)## Project BriefBuild a production-grade document Q&A system that:1. Ingests PDF/TXT/MD documents2. Chunks and embeds them into a vector store3. Answers questions using RAG with source citations4. Evaluates its own answer quality5. Supports multi-model switching### Requirements| Feature | Details ||---------|---------|| Document ingestion | PDF, TXT, Markdown support || Chunking | Recursive character + semantic chunking || Vector store | ChromaDB with persistence || Retrieval | Hybrid search (semantic + keyword) || Generation | Multi-model via litellm || Citations | Every answer cites source document + page || Evaluation | Faithfulness + relevance scoring || UI | Simple CLI or Jupyter Widgets interface |### Grading Rubric- ✅ Core RAG pipeline works (ingestion → retrieval → generation)- ✅ Citations are accurate and traceable- ✅ Handles at least 3 document formats- ✅ Evaluation scores reported per answer- ⭐ Bonus: Multi-document comparison queries- ⭐ Bonus: Conversational follow-up support

# %% [markdown]
# ## Step 1: Setup & Document Ingestion

# %%
# TODO: Your implementation# Hints:# - Use pypdf for PDFs, built-in open() for txt/md# - Implement recursive character splitter from NB04# - Store metadata: filename, page_number, chunk_indeximport os, jsonfrom dotenv import load_dotenvimport litellmload_dotenv()DEFAULT_MODEL = os.getenv("DEFAULT_MODEL", "gpt-4o-mini")DEFAULT_EMBEDDING = os.getenv("DEFAULT_EMBEDDING_MODEL", "text-embedding-3-small")print(f"🤖 Model: {DEFAULT_MODEL}")print(f"📐 Embedding: {DEFAULT_EMBEDDING}")# Your document loader hereclass DocumentLoader:    pass  # Implement# Your chunker hereclass Chunker:    pass  # Implement

# %% [markdown]
# ## Step 2: Vector Store & Retrieval

# %%
# TODO: Your implementation# Hints:# - Use ChromaDB with persistence# - Implement hybrid search (NB05)# - Store metadata with each embeddingclass VectorStore:    pass  # Implementclass HybridRetriever:    pass  # Implement

# %% [markdown]
# ## Step 3: RAG Pipeline with Citations

# %%
# TODO: Your implementation# Hints:# - Inject retrieved chunks into LLM context# - Extract source references from metadata# - Format citations: [Source: doc.pdf, Page 5]class RAGPipeline:    def query(self, question):        # 1. Retrieve relevant chunks        # 2. Build context with source references        # 3. Call LLM with context        # 4. Add citations to response        pass

# %% [markdown]
# ## Step 4: Evaluation

# %%
# TODO: Your implementation# Hints:# - Reuse the RAGEvaluator from NB15# - Score each answer: faithfulness, relevance# - Log results for analysisclass QAEvaluator:    pass  # Implement

# %% [markdown]
# ## Step 5: Putting It All Together

# %%
# TODO: Build the complete system# - Load documents# - Chunk and embed# - Interactive Q&A loop# - Show answer + citations + evaluation scoresdef main():    print("📚 Document Q&A System")    print("=" * 50)    # Your implementation    passmain()

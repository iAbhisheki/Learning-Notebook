# %% [markdown]
# # 🏆 Capstone 2 — Multi-Agent Research System---**Skills Used:** Notebooks 07–14 (Tools, ReAct, Memory, Planning, Multi-Agent)## Project BriefBuild a multi-agent system that conducts deep research on any topic:1. A **Manager** agent decomposes the topic into research questions2. Multiple **Researcher** agents investigate each question3. A **Writer** agent synthesizes findings into a report4. A **Reviewer** agent critiques and scores the report  5. A **Reflector** agent improves the report based on critique### Requirements| Feature | Details ||---------|---------|| Manager | Decomposes topic into 3-5 sub-questions || Researchers | Each researches one question with tools || Writer | Synthesizes findings into structured report || Reviewer | Scores report 1-10 with specific feedback || Reflector | Improves report until score ≥ 8 || Memory | Persistent memory across research sessions || Logging | Full trace of every agent action || Tools | Web search, calculation, summarization |### Grading Rubric- ✅ Multi-agent coordination works end-to-end- ✅ Each agent has clear, specialized role- ✅ Research trace is fully logged and reviewable- ✅ Report quality improves through reflection- ⭐ Bonus: Parallel researcher execution- ⭐ Bonus: Cross-session memory persistence

# %% [markdown]
# ## Step 1: Define Agent Roles

# %%
# TODO: Define specialized agents# Hints:# - Each agent needs: name, role, system_prompt# - Manager: task decomposition# - Researcher: fact-finding with tools# - Writer: report generation# - Reviewer: quality evaluation# - Reflector: improvement based on feedbackimport os, jsonfrom dotenv import load_dotenvimport litellmload_dotenv()DEFAULT_MODEL = os.getenv("DEFAULT_MODEL", "gpt-4o-mini")class SpecializedAgent:    def __init__(self, name, role, system_prompt, tools=None):        pass  # Implement        def run(self, task, context=""):        pass  # Implement

# %% [markdown]
# ## Step 2: Tool Registry

# %%
# TODO: Register tools for researcher agents# Hints:# - search: web/knowledge search# - calculate: math operations# - summarize: text compressionclass ToolRegistry:    pass  # Implement

# %% [markdown]
# ## Step 3: Orchestrator

# %%
# TODO: Build the orchestration pipeline# Hints:# - Manager → split task# - Fan-out researchers → parallel execution# - Writer → synthesize# - Reviewer → score# - If score < 8: Reflector → improve → re-reviewclass ResearchOrchestrator:    def research(self, topic):        # 1. Manager decomposes        # 2. Researchers investigate (fan-out)        # 3. Writer synthesizes (fan-in)        # 4. Reviewer evaluates        # 5. Reflect if needed        pass

# %% [markdown]
# ## Step 4: Run Research

# %%
# TODO: Run the full research pipelineorchestrator = ResearchOrchestrator()# result = orchestrator.research("The future of AI-powered software development")
